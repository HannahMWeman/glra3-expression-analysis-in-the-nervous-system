# %% [markdown]
# # Nervous system widespread analysis of Glra3 expression in Zeisel et al dataset
#
# The following analysis was performed for our article; , where we wanted to investigate the expression of Glra3 in distinct areas of the central nervous system as well as bodily organs in both female and male mice to investigate if there are any expressional differences between the sexes. Using qPCR, we found that ()
#
# For the following analysis, we wanted to validate the expressional findings from the qPCR with analysis of pre-existing single-cell mRNA sequencing data. Here, we are invesigating the Glra3 expression in the different areas of the nervous system, including the peripheral nervous system, spinal cord and brain. The analysis was conducted on the Zeisel et al (2018) dataset [1]. The dataset 'l5_all.loom' was aquired from (http://mousebrain.org/) and contains expressional data from 27,998 genes in 160,796 cells. The dataset was analysed using SCANPY [2].
#
# The major findings of this sequencing analysis is that Glra3 is lowly expressed in a number of different areas brain areas and spinal cord- both excitatory and inhibitory neurons, as well as in hindbrain and enteric neurons. Expression was however not found in peripheral neurons nor the cerebellum.
#
#
#
# References;
#
#
# [1] Zeisel, A., Hochgerner, H., Lönnerberg, P. et al. (2018). Molecular Architecture of the Mouse Nervous System. Cell, doi: 10.1016/j.cell.2018.06.021
#
# [2] Wolf, F.A.,Angerer, P., Theis, F.J. 2018. SCANPY: large-scale single-cell gene expression data analysis.

# %%
# import necessary modules 
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import loompy

# make the text in figures editable in Illustrator
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %% [markdown]
# The following functions were used for analysis of the Zeisel et al dataset

# %%
"""function for calculating the percentage of cells expressing gene of interest"""
def percentage_exp(adata, genes):
    per_list = []
    for gene in genes:
        percentage = len(adata[adata[:, gene].X > 0.1])/len(adata.X) # calculate the percentage of cells expressing gene(s) of interest
        per_list.append((gene, percentage*100)) # add the name of gene and the percentage to list
    return sorted(per_list, key=lambda tup: tup[1], reverse = True) #rank the level of prevalence in list

"""function for calculating the number of cells expressing gene of interest"""
def number_exp(adata, genes):
    num_list = []
    for gene in genes:
        percentage = len(adata[adata[:, gene].X > 0.1])/len(adata.X)# calculate the percentage of cells expressing gene(s) of interest
        num_list.append((gene, percentage*len(adata.X))) # add the name of gene and the number of cells expressing gene of intererest
    return sorted(num_list, key=lambda tup: tup[1], reverse = True) #rank the level of prevalence in list
                                                           
    

"""function for calculating the number of cells belonging to specific categorical observation"""
def calc_celltype_observation(adata, observation):
    pd_adata = pd.DataFrame(index = adata.obs_names, columns = adata.var_names, data = adata.X) #convert AnnData object to a dataframe. 
    # does not work to make calculations directly onthe AnnData object
    pd_adata['obs_name'] = adata.obs[observation] #create new column in dataframe depending on the target observation in the AnnData object
    pd_celltype = pd.DataFrame(pd_adata.loc[pd_adata.index, 'obs_name']) # extract the index and the target observation
    pd_celltype = pd.DataFrame(pd_adata.groupby('obs_name').size(), columns = ['number_cells']) #calculate the number of cells belonging to each 
    return(pd_celltype)

# %%
# read the Zeisel et al dataset
adata = sc.read_loom('l5_all.loom', sparse = False)
adata
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# AnnData object with n_obs × n_vars = 160796 × 27998
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid'

# %%
# isolate all true neurons in the dataset
adata = adata[adata.obs['Class'] == 'Neurons']
adata
# Out:
# View of AnnData object with n_obs × n_vars = 74539 × 27998
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid'

# %%
calc_celltype_observation(adata, 'TaxonomyRank1')
# Out:
#           number_cells
# obs_name
# Neurons          74539

# %%
calc_celltype_observation(adata, 'TaxonomyRank2')
# Out:
#              number_cells
# obs_name
# CNS neurons         70968
# PNS neurons          3571

# %%
calc_celltype_observation(adata, 'TaxonomyRank3')
# Out:
#                                                     number_cells
# obs_name
# Cerebellum neurons                                          5292
# Cholinergic, monoaminergic and peptidergic neurons          3977
# Di- and mesencephalon neurons                              10481
# Enteric neurons                                             1105
# Hindbrain neurons                                           1144
# Immature neural                                             5466
# Peripheral sensory neurons                                  1580
# Spinal cord neurons                                         1922
# Sympathetic neurons                                          886
# Telencephalon interneurons                                 13828
# Telencephalon projecting neurons                           28858

# %%
calc_celltype_observation(adata, 'TaxonomyRank4')
# Out:
#                                              number_cells
# obs_name
# Cerebellum neurons                                   5292
# Cholinergic and monoaminergic neurons                1071
# Dentate gyrus granule neurons                        4368
# Di- and mesencephalon excitatory neurons             6455
# Di- and mesencephalon inhibitory neurons             4026
# Enteric neurons                                      1105
# Glutamatergic neuroblasts                             644
# Hindbrain neurons                                    1144
# Non-glutamatergic neuroblasts                        4822
# Olfactory inhibitory neurons                         5191
# Peptidergic neurons                                  2906
# Peripheral sensory neurofilament neurons              126
# Peripheral sensory non-peptidergic neurons            889
# Peripheral sensory peptidergic neurons                565
# Spinal cord excitatory neurons                       1166
# Spinal cord inhibitory neurons                        756
# Sympathetic cholinergic neurons                        90
# Sympathetic noradrenergic neurons                     796
# Telencephalon inhibitory interneurons                8637
# Telencephalon projecting excitatory neurons         18799
# Telencephalon projecting inhibitory neurons          5691

# %%
calc_celltype_observation(adata, 'Description')
# Out:
#                                                     number_cells
# obs_name
# Adrenergic cell groups of the medulla                         40
# Afferent nuclei of cranial nerves III-V                       52
# Afferent nuclei of cranial nerves VI-XII                      72
# Axo-axonic, cortex/hippocampus                               675
# Basket and bistratified cells, cortex/hippocampus            547
# ...                                                          ...
# R-LM border Cck interneurons, cortex/hippocampus            1241
# Serotonergic neurons, hindbrain                              437
# Sleep-active, long-range projection interneuron...           385
# Trilaminar cells, hippocampus                                163
# Vasopressin-producing cells, hypothalamus                    173
#
# [93 rows x 1 columns]

# %%
calc_celltype_observation(adata, 'Region')
# Out:
#                                                   number_cells
# obs_name
# Amygdala                                                   958
# Cerebellum                                                5249
# Cortex                                                   15216
# Dentate gyrus                                             6194
# Dorsal root ganglion                                      1580
# Enteric nervous system                                    1105
# Hippocampus                                               3214
# Hippocampus,Cortex                                        7542
# Hypothalamus                                              2033
# Medulla                                                   1573
# Midbrain dorsal                                           5226
# Midbrain dorsal,Midbrain ventral                           461
# Midbrain ventral                                           316
# Olfactory bulb                                            7795
# Pallidum                                                   838
# Pons                                                      1207
# Pons,Medullae,Cerebellum                                   163
# Spinal cord                                               1812
# Striatum dorsal                                           1963
# Striatum dorsal, Striatum ventral                         1339
# Striatum dorsal, Striatum ventral, Dentate gyrus           971
# Striatum dorsal, Striatum ventral,Amygdala                 121
# Striatum ventral                                          3728
# Sympathetic ganglion                                       886
# Thalamus                                                  3049

# %%
# filter out cells expressing less than 200 different genes and genes found in less than 3 cells
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
adata

# make variables and observations unique
adata.var_names_make_unique()
adata.obs_names_make_unique()
adata
# Out:
# Trying to set attribute `.obs` of view, copying.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# AnnData object with n_obs × n_vars = 74529 × 21194
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA', 'n_genes'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid', 'n_cells'

# %%
# no ERCC genes identified, do not use to calulate metrics
print([name for name in adata.var_names if name.startswith('ERCC')])
print([name for name in adata.var_names if name.startswith('ercc')])

# %%
# add the total counts per cell as observation
adata.obs['n_counts'] = np.sum(adata.X, axis=1)

# annotate the group of mitochondrial genes as 'mt'
adata.var['mt'] = adata.var_names.str.startswith('mt-')  
# calulate the general metrics and metrics based on mitochondrial genes
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], inplace=True)

# make variables and observations unique
adata.var_names_make_unique()
adata.obs_names_make_unique()
adata
# Out:
# AnnData object with n_obs × n_vars = 74529 × 21194
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
#plot some general information and the mitochondrial data
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# make variables and observations unique
adata.var_names_make_unique()
adata.obs_names_make_unique()
adata
# Out:
# ... storing 'Age' as categorical
# ... storing 'AnalysisPool' as categorical
# ... storing 'AnalysisProject' as categorical
# ... storing 'Bucket' as categorical
# ... storing 'CellConc' as categorical
# ... storing 'Cell_Conc' as categorical
# ... storing 'ChipID' as categorical
# ... storing 'Class' as categorical
# ... storing 'ClusterName' as categorical
# ... storing 'Comment' as categorical
# ... storing 'Comments' as categorical
# ... storing 'DateCaptured' as categorical
# ... storing 'Date_Captured' as categorical
# ... storing 'Description' as categorical
# ... storing 'Developmental_compartment' as categorical
# ... storing 'DonorID' as categorical
# ... storing 'Estimated Number of Cells' as categorical
# ... storing 'Flowcell' as categorical
# ... storing 'Fraction Reads in Cells' as categorical
# ... storing 'Label' as categorical
# ... storing 'Location_based_on' as categorical
# ... storing 'Mean Reads per Cell' as categorical
# ... storing 'Median Genes per Cell' as categorical
# ... storing 'Median UMI Counts per Cell' as categorical
# ... storing 'NGI_PlateWell' as categorical
# ... storing 'Neurotransmitter' as categorical
# ... storing 'NumPooledAnimals' as categorical
# ... storing 'Num_Pooled_Animals' as categorical
# ... storing 'Number of Reads' as categorical
# ... storing 'PCRCycles' as categorical
# ... storing 'PCR_Cycles' as categorical
# ... storing 'PassedQC' as categorical
# ... storing 'PlugDate' as categorical
# ... storing 'Plug_Date' as categorical
# ... storing 'Probable_location' as categorical
# ... storing 'Project' as categorical
# ... storing 'Q30 Bases in Barcode' as categorical
# ... storing 'Q30 Bases in RNA Read' as categorical
# ... storing 'Q30 Bases in Sample Index' as categorical
# ... storing 'Q30 Bases in UMI' as categorical
# ... storing 'Reads Mapped Confidently to Exonic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intergenic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intronic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Transcriptome' as categorical
# ... storing 'Region' as categorical
# ... storing 'SampleID' as categorical
# ... storing 'SampleIndex' as categorical
# ... storing 'SampleOK' as categorical
# ... storing 'Sample_Index' as categorical
# ... storing 'SeqComment' as categorical
# ... storing 'SeqLibDate' as categorical
# ... storing 'SeqLibOk' as categorical
# ... storing 'Seq_Comment' as categorical
# ... storing 'Seq_Lib_Date' as categorical
# ... storing 'Seq_Lib_Ok' as categorical
# ... storing 'Sequencing Saturation' as categorical
# ... storing 'Serial_Number' as categorical
# ... storing 'Sex' as categorical
# ... storing 'Species' as categorical
# ... storing 'Strain' as categorical
# ... storing 'Subclass' as categorical
# ... storing 'TargetNumCells' as categorical
# ... storing 'Target_Num_Cells' as categorical
# ... storing 'TaxonomyRank1' as categorical
# ... storing 'TaxonomyRank2' as categorical
# ... storing 'TaxonomyRank3' as categorical
# ... storing 'TaxonomyRank4' as categorical
# ... storing 'TaxonomySymbol' as categorical
# ... storing 'Taxonomy_group' as categorical
# ... storing 'TimepointPool' as categorical
# ... storing 'Tissue' as categorical
# ... storing 'Total Genes Detected' as categorical
# ... storing 'Transcriptome' as categorical
# ... storing 'Valid Barcodes' as categorical
# ... storing 'cDNAConcNanogramPerMicroliter' as categorical
# ... storing 'cDNALibOk' as categorical
# ... storing 'cDNA_Lib_Ok' as categorical
# ... storing 'ngperul_cDNA' as categorical
# AnnData object with n_obs × n_vars = 74529 × 21194
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
# make variables and observations unique
adata.var_names_make_unique()
adata.obs_names_make_unique()

# %%
# plot the distribution of logaritmized total counts. Want to include cells with higher counts
# to avoid smaller cells such as glial cells
sns.distplot(adata.obs['log1p_total_counts'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='log1p_total_counts', ylabel='Density'>

# %%
# plot the logaritmized number of genes by counts and the percentage of counts that express the top 50 most expressed genes
sns.jointplot('log1p_n_genes_by_counts', 'pct_counts_in_top_50_genes', data=adata.obs, kind="hex")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# do the actual filtering to exclude cells 
adata = adata[adata.obs.pct_counts_mt < 20, :] # include cells with low mithochondrial expression
adata = adata[adata.obs.log1p_total_counts > 6.5, :]
adata = adata[adata.obs.pct_counts_in_top_50_genes < 50, :] # filter cells with distributed gene counts
adata = adata[adata.obs.log1p_n_genes_by_counts > 6.0, :] # filter cells with broad gene capture

# %%
# normalize the number of reads per cell to the median number of reads
sc.pp.normalize_per_cell(adata, counts_per_cell_after= adata.obs['n_counts'].median())
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
# logaritmize data
sc.pp.log1p(adata)

adata
# Out:
# AnnData object with n_obs × n_vars = 72020 × 21194
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'log1p'

# %%
calc_celltype_observation(adata, 'Region')
# Out:
#                                                   number_cells
# obs_name
# Amygdala                                                   956
# Cerebellum                                                3240
# Cortex                                                   15205
# Dentate gyrus                                             6177
# Dorsal root ganglion                                      1580
# Enteric nervous system                                     943
# Hippocampus                                               3210
# Hippocampus,Cortex                                        7507
# Hypothalamus                                              1981
# Medulla                                                   1566
# Midbrain dorsal                                           5204
# Midbrain dorsal,Midbrain ventral                           460
# Midbrain ventral                                           313
# Olfactory bulb                                            7763
# Pallidum                                                   832
# Pons                                                      1196
# Pons,Medullae,Cerebellum                                   158
# Spinal cord                                               1790
# Striatum dorsal                                           1962
# Striatum dorsal, Striatum ventral                         1332
# Striatum dorsal, Striatum ventral, Dentate gyrus           933
# Striatum dorsal, Striatum ventral,Amygdala                 121
# Striatum ventral                                          3676
# Sympathetic ganglion                                       886
# Thalamus                                                  3029

# %% [markdown]
# ## Analysis of Glra3 expression in all neurons based on nervous system area

# %% [markdown]
# From violin plot, can see that Glra3 is expressed lowly, but widespreadly expressed in the nervous system

# %%
sc.pl.violin(adata, 'Glra3', use_raw = False, stripplot= True, jitter = 0.4, groupby = 'TaxonomyRank4', 
             rotation =85, save= 'violin_glra3_expression.pdf')
# Out:
# WARNING: saving figure to file figures/violinviolin_glra3_expression.pdf

# %%
sc.pl.violin(adata, 'Glra3', use_raw = False, stripplot= True, jitter = 0.4, groupby = 'Region', 
             rotation =85, save= 'violin_glra3_expression_region.pdf')
# Out:
# WARNING: saving figure to file figures/violinviolin_glra3_expression_region.pdf

# %% [markdown]
# Here, the expression of Glra3, as well as Slc17a6 (Vglut2, excitatory marker) and Slc32a1 (Viaat, inhibitory marker) was investigated in all neurons of the respective nervous system areas using a dotplot. Even more here, we can see that Glra3 is lowly expressed in a small portion of the respective Glra3 expressing area

# %%
marker_genes = ['Slc17a6','Slc32a1','Ucn3']
labels = ['Excitatory', 'Inhibitory', 'Urocortin 3']
label_pos = [(0,0), (1,1), (2,2)]
order_cat = ['Olfactory inhibitory neurons', 'Telencephalon projecting excitatory neurons', 'Telencephalon projecting inhibitory neurons',
             'Telencephalon inhibitory interneurons', 'Di- and mesencephalon excitatory neurons', 
             'Di- and mesencephalon inhibitory neurons', 'Cholinergic and monoaminergic neurons', 
             'Peptidergic neurons', 'Dentate gyrus granule neurons', 'Glutamatergic neuroblasts', 'Non-glutamatergic neuroblasts', 
             'Cerebellum neurons', 'Hindbrain neurons', 'Spinal cord excitatory neurons', 
             'Spinal cord inhibitory neurons', 'Peripheral sensory neurofilament neurons', 
             'Peripheral sensory non-peptidergic neurons', 'Peripheral sensory peptidergic neurons', 
             'Sympathetic cholinergic neurons', 'Sympathetic noradrenergic neurons', 'Enteric neurons']

sc.pl.DotPlot(adata, marker_genes, var_group_labels =labels, var_group_positions= label_pos, 
                          use_raw = False, groupby = 'TaxonomyRank4', categories_order= order_cat, cmap ='mako_r').add_totals(color = 'rosybrown').savefig('ucn3_marker_expression_all.pdf')

# %%
marker_genes = ['Slc17a6','Slc32a1','Slc18a2']
labels = ['Excitatory', 'Inhibitory', 'Vmat2']
label_pos = [(0,0), (1,1), (2,2)]
order_cat = ['Olfactory inhibitory neurons', 'Telencephalon projecting excitatory neurons', 'Telencephalon projecting inhibitory neurons',
             'Telencephalon inhibitory interneurons', 'Di- and mesencephalon excitatory neurons', 
             'Di- and mesencephalon inhibitory neurons', 'Cholinergic and monoaminergic neurons', 
             'Peptidergic neurons', 'Dentate gyrus granule neurons', 'Glutamatergic neuroblasts', 'Non-glutamatergic neuroblasts', 
             'Cerebellum neurons', 'Hindbrain neurons', 'Spinal cord excitatory neurons', 
             'Spinal cord inhibitory neurons', 'Peripheral sensory neurofilament neurons', 
             'Peripheral sensory non-peptidergic neurons', 'Peripheral sensory peptidergic neurons', 
             'Sympathetic cholinergic neurons', 'Sympathetic noradrenergic neurons', 'Enteric neurons']

sc.pl.DotPlot(adata, marker_genes, var_group_labels =labels, var_group_positions= label_pos, 
                          use_raw = False, groupby = 'TaxonomyRank4', categories_order= order_cat, cmap ='mako_r').add_totals(color = 'rosybrown').savefig('ucn3_marker_expression_all.pdf')

# %%
marker_genes = ['Slc17a6','Slc32a1','Ucn3']
labels = ['Excitatory', 'Inhibitory', 'Urocortin 3']
label_pos = [(0,0), (1,1), (2,2)]
order_cat = ['Olfactory bulb', 
             'Cortex', 'Amygdala', 
             'Pallidum', 'Striatum dorsal', 
             'Striatum dorsal, Striatum ventral,Amygdala', 
             'Striatum dorsal, Striatum ventral', 'Striatum ventral', 'Striatum dorsal, Striatum ventral, Dentate gyrus',           
             'Hypothalamus', 'Thalamus', 'Hippocampus,Cortex', 'Hippocampus', 
             'Dentate gyrus', 'Midbrain dorsal', 'Midbrain dorsal,Midbrain ventral', 
             'Midbrain ventral',  'Pons,Medullae,Cerebellum', 'Cerebellum', 'Pons',
             'Medulla', 'Spinal cord', 'Sympathetic ganglion', 'Dorsal root ganglion',
             'Enteric nervous system']                                                                     

sc.pl.DotPlot(adata, marker_genes,var_group_labels =labels, 
              var_group_positions= label_pos, categories_order= order_cat,
              use_raw = False, groupby = 'Region', cmap ='mako_r').add_totals(color = 'rosybrown').savefig('ucn3_marker_expression_all_region.pdf')

# %%
marker_genes = ['Slc17a6','Slc32a1','Slc18a2']
labels = ['Excitatory', 'Inhibitory', 'Vmat2']
label_pos = [(0,0), (1,1), (2,2)]
order_cat = ['Olfactory bulb', 
             'Cortex', 'Amygdala', 
             'Pallidum', 'Striatum dorsal', 
             'Striatum dorsal, Striatum ventral,Amygdala', 
             'Striatum dorsal, Striatum ventral', 'Striatum ventral', 'Striatum dorsal, Striatum ventral, Dentate gyrus',           
             'Hypothalamus', 'Thalamus', 'Hippocampus,Cortex', 'Hippocampus', 
             'Dentate gyrus', 'Midbrain dorsal', 'Midbrain dorsal,Midbrain ventral', 
             'Midbrain ventral',  'Pons,Medullae,Cerebellum', 'Cerebellum', 'Pons',
             'Medulla', 'Spinal cord', 'Sympathetic ganglion', 'Dorsal root ganglion',
             'Enteric nervous system']                                                                     

sc.pl.DotPlot(adata, marker_genes,var_group_labels =labels, 
              var_group_positions= label_pos, categories_order= order_cat,
              use_raw = False, groupby = 'Region', cmap ='mako_r').add_totals(color = 'rosybrown').savefig('vmat2_marker_expression_all_region.pdf')

# %% [markdown]
# To further investigate the Glra3 expressing neurons, the expression of Glra3 is plotted as a scatter plot in order to set a expression level threshold (where cells are considered to express Glra3). Based on this plot, the threshold is set to 0.1 (log1p value)

# %%
sc.pl.scatter(adata, x = 'Glra3', y = 'Actb', color = 'Description')

# %%
adata.obs['glra3_cell'] = (adata[:, 'Glra3'].X > 0.1).astype(str)

# %% [markdown]
# The prevalence of expression of targeted Glr genes is investigated in all neurons in the dataset

# %%
glyr_genes = [gene for gene in adata.var_names if gene.startswith('Glr')]

percentage_exp(adata, glyr_genes)
# Out:
# [('Glrx5', 60.96639822271591),
#  ('Glrx2', 43.49486253818384),
#  ('Glrx3', 43.151902249375176),
#  ('Glrb', 32.53957234101638),
#  ('Glrx', 21.178839211330185),
#  ('Glra2', 6.303804498750347),
#  ('Glra1', 3.9975006942515967),
#  ('Glra3', 0.8719800055540128),
#  ('Glrp1', 0.037489586226048324),
#  ('Glra4', 0.020827547903360177)]

# %%
# isolate the Glra3 expressing cells
adata_glra3 = adata[adata.obs['glra3_cell'] == 'True']
adata_glra3
# Out:
# View of AnnData object with n_obs × n_vars = 628 × 21194
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA', 'n_genes', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'glra3_cell'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'log1p', 'TaxonomyRank4_colors', 'Region_colors', 'Description_colors'

# %% [markdown]
# Calculate the percentage of cells in each nervous system area that expressed Glra3

# %%
df_glra3 = calc_celltype_observation(adata_glra3, 'TaxonomyRank4')
df_all = calc_celltype_observation(adata, 'TaxonomyRank4')

print(df_glra3)
print(df_all)

# print the percentage of neurons from each cluster expressing Glra3
print(df_glra3.div(df_all)*100)
# Out:
#                                              number_cells
# obs_name
# Cholinergic and monoaminergic neurons                  25
# Dentate gyrus granule neurons                           1
# Di- and mesencephalon excitatory neurons              197
# Di- and mesencephalon inhibitory neurons               43
# Enteric neurons                                         1
# Glutamatergic neuroblasts                               4
# Hindbrain neurons                                      18
# Peptidergic neurons                                    29
# Spinal cord excitatory neurons                         35
# Spinal cord inhibitory neurons                         28
# Telencephalon inhibitory interneurons                  21
# Telencephalon projecting excitatory neurons           212
# Telencephalon projecting inhibitory neurons            14
#                                              number_cells
# obs_name
# Cerebellum neurons                                   3283
# Cholinergic and monoaminergic neurons                1064
# Dentate gyrus granule neurons                        4357
# Di- and mesencephalon excitatory neurons             6422
# Di- and mesencephalon inhibitory neurons             4015
# Enteric neurons                                       943
# Glutamatergic neuroblasts                             635
# Hindbrain neurons                                    1132
# Non-glutamatergic neuroblasts                        4773
# Olfactory inhibitory neurons                         5168
# Peptidergic neurons                                  2844
# Peripheral sensory neurofilament neurons              126
# Peripheral sensory non-peptidergic neurons            889
# Peripheral sensory peptidergic neurons                565
# Spinal cord excitatory neurons                       1149
# Spinal cord inhibitory neurons                        750
# Sympathetic cholinergic neurons                        90
# Sympathetic noradrenergic neurons                     796
# Telencephalon inhibitory interneurons                8599
# Telencephalon projecting excitatory neurons         18782
# Telencephalon projecting inhibitory neurons          5638
#                                              number_cells
# obs_name
# Cerebellum neurons                                    NaN
# Cholinergic and monoaminergic neurons            2.349624
# Dentate gyrus granule neurons                    0.022952
# Di- and mesencephalon excitatory neurons         3.067580
# Di- and mesencephalon inhibitory neurons         1.070984
# Enteric neurons                                  0.106045
# Glutamatergic neuroblasts                        0.629921
# Hindbrain neurons                                1.590106
# Non-glutamatergic neuroblasts                         NaN
# Olfactory inhibitory neurons                          NaN
# Peptidergic neurons                              1.019691
# Peripheral sensory neurofilament neurons              NaN
# Peripheral sensory non-peptidergic neurons            NaN
# Peripheral sensory peptidergic neurons                NaN
# Spinal cord excitatory neurons                   3.046127
# Spinal cord inhibitory neurons                   3.733333
# Sympathetic cholinergic neurons                       NaN
# Sympathetic noradrenergic neurons                     NaN
# Telencephalon inhibitory interneurons            0.244214
# Telencephalon projecting excitatory neurons      1.128740
# Telencephalon projecting inhibitory neurons      0.248315

# %%
df_glra3 = calc_celltype_observation(adata_glra3, 'Region')
df_all = calc_celltype_observation(adata, 'Region')

print(df_glra3)
print(df_all)

# print the percentage of neurons from each cluster expressing Glra3
print(df_glra3.div(df_all)*100)
# Out:
#                                             number_cells
# obs_name
# Amygdala                                              29
# Cortex                                               176
# Dentate gyrus                                          1
# Enteric nervous system                                 1
# Hippocampus                                            7
# Hippocampus,Cortex                                    20
# Hypothalamus                                          21
# Medulla                                               53
# Midbrain dorsal                                      181
# Midbrain dorsal,Midbrain ventral                       6
# Midbrain ventral                                       6
# Olfactory bulb                                         4
# Pallidum                                               5
# Pons                                                  18
# Spinal cord                                           57
# Striatum dorsal, Striatum ventral                     14
# Striatum dorsal, Striatum ventral,Amygdala             2
# Striatum ventral                                      14
# Thalamus                                              13
#                                                   number_cells
# obs_name
# Amygdala                                                   956
# Cerebellum                                                3240
# Cortex                                                   15205
# Dentate gyrus                                             6177
# Dorsal root ganglion                                      1580
# Enteric nervous system                                     943
# Hippocampus                                               3210
# Hippocampus,Cortex                                        7507
# Hypothalamus                                              1981
# Medulla                                                   1566
# Midbrain dorsal                                           5204
# Midbrain dorsal,Midbrain ventral                           460
# Midbrain ventral                                           313
# Olfactory bulb                                            7763
# Pallidum                                                   832
# Pons                                                      1196
# Pons,Medullae,Cerebellum                                   158
# Spinal cord                                               1790
# Striatum dorsal                                           1962
# Striatum dorsal, Striatum ventral                         1332
# Striatum dorsal, Striatum ventral, Dentate gyrus           933
# Striatum dorsal, Striatum ventral,Amygdala                 121
# Striatum ventral                                          3676
# Sympathetic ganglion                                       886
# Thalamus                                                  3029
#                                                   number_cells
# obs_name
# Amygdala                                              3.033473
# Cerebellum                                                 NaN
# Cortex                                                1.157514
# Dentate gyrus                                         0.016189
# Dorsal root ganglion                                       NaN
# Enteric nervous system                                0.106045
# Hippocampus                                           0.218069
# Hippocampus,Cortex                                    0.266418
# Hypothalamus                                          1.060071
# Medulla                                               3.384419
# Midbrain dorsal                                       3.478094
# Midbrain dorsal,Midbrain ventral                      1.304348
# Midbrain ventral                                      1.916933
# Olfactory bulb                                        0.051526
# Pallidum                                              0.600962
# Pons                                                  1.505017
# Pons,Medullae,Cerebellum                                   NaN
# Spinal cord                                           3.184358
# Striatum dorsal                                            NaN
# Striatum dorsal, Striatum ventral                     1.051051
# Striatum dorsal, Striatum ventral, Dentate gyrus           NaN
# Striatum dorsal, Striatum ventral,Amygdala            1.652893
# Striatum ventral                                      0.380849
# Sympathetic ganglion                                       NaN
# Thalamus                                              0.429185

# %%
df_glra3 = calc_celltype_observation(adata_glra3, 'Description')
df_all = calc_celltype_observation(adata, 'Description')

print(df_glra3)
print(df_all)

# print the percentage of neurons from each cluster expressing Glra3
print(df_glra3.div(df_all)*100)
# Out:
#                                                     number_cells
# obs_name
# Adrenergic cell groups of the medulla                          1
# Afferent nuclei of cranial nerves III-V                        4
# Afferent nuclei of cranial nerves VI-XII                       5
# Axo-axonic, cortex/hippocampus                                 1
# CGE-derived neurogliaform cells Cxcl14+, cortex...             3
# Cholinergic enteric neurons, VGLUT2                            1
# Cholinergic interneurons, telencephalon                        2
# Cholinergic neurons, hindbrain                                 6
# Cholinergic neurons, midbrain red nucleus                      1
# D1 medium spiny neurons, striatum                              4
# D2 medium spiny neurons, striatum                              9
# Dopaminergic neurons, ventral midbrain (SNc, VTA)              4
# Excitatory neurons, amygdala                                  29
# Excitatory neurons, cerebral cortex                          176
# Excitatory neurons, hindbrain                                 25
# Excitatory neurons, hippocampus CA1                            3
# Excitatory neurons, hippocampus CA3                            4
# Excitatory neurons, hypothalamus                               1
# Excitatory neurons, midbrain                                 162
# Excitatory neurons, spinal cord                               34
# Excitatory neurons, thalamus                                  12
# Granule neurons, dentate gyrus                                 1
# Hippocamposeptal projection, cortex/hippocampus               11
# Inhibitory neurons, hindbrain                                 22
# Inhibitory neurons, hypothalamus                               4
# Inhibitory neurons, midbrain                                  26
# Inhibitory neurons, pallidum                                   5
# Inhibitory neurons, septal nucleus                            14
# Inhibitory neurons, spinal cord                               23
# Inhibitory neurons, thalamus                                   1
# Interneuron-selective interneurons, cortex/hipp...             2
# Neuroblasts, olfactory                                         2
# Neuroblasts, olfactory bulb                                    2
# Non-border Cck interneurons, cortex/hippocampus                2
# Orexin-producing neurons, hypothalamus                         1
# Patch D1/D2 neurons, striatum                                  1
# Peptidergic neurons, hypothalamus                             15
# R-LM border Cck interneurons, cortex/hippocampus               1
# Serotonergic neurons, hindbrain                                8
#                                                     number_cells
# obs_name
# Adrenergic cell groups of the medulla                         40
# Afferent nuclei of cranial nerves III-V                       52
# Afferent nuclei of cranial nerves VI-XII                      71
# Axo-axonic, cortex/hippocampus                               667
# Basket and bistratified cells, cortex/hippocampus            547
# ...                                                          ...
# R-LM border Cck interneurons, cortex/hippocampus            1239
# Serotonergic neurons, hindbrain                              436
# Sleep-active, long-range projection interneuron...           382
# Trilaminar cells, hippocampus                                163
# Vasopressin-producing cells, hypothalamus                    168
#
# [93 rows x 1 columns]
#                                                     number_cells
# obs_name
# Adrenergic cell groups of the medulla                   2.500000
# Afferent nuclei of cranial nerves III-V                 7.692308
# Afferent nuclei of cranial nerves VI-XII                7.042254
# Axo-axonic, cortex/hippocampus                          0.149925
# Basket and bistratified cells, cortex/hippocampus            NaN
# ...                                                          ...
# R-LM border Cck interneurons, cortex/hippocampus        0.080710
# Serotonergic neurons, hindbrain                         1.834862
# Sleep-active, long-range projection interneuron...           NaN
# Trilaminar cells, hippocampus                                NaN
# Vasopressin-producing cells, hypothalamus                    NaN
#
# [93 rows x 1 columns]

# %% [markdown]
# ### Analysis of Glra3 expression overlap with Vglut2 and Viaat in the respective nervous system areas
#
# Here we are investigating the expression of Vglut2 and Viaat in the Glra3 neurons of each of the areas. Again the expression of the targeted genes are investigated using a dotplot.
#
# There is an expected overlap with the respective excitatory or inhibitory marker depending on the area.

# %%
order_cat_glra3 = ['Olfactory bulb', 
             'Cortex', 'Amygdala', 
             'Pallidum','Striatum dorsal, Striatum ventral,Amygdala', 
             'Striatum dorsal, Striatum ventral', 'Striatum ventral',           
             'Hypothalamus', 'Thalamus', 'Hippocampus,Cortex', 'Hippocampus', 
             'Dentate gyrus', 'Midbrain dorsal', 'Midbrain dorsal,Midbrain ventral', 
             'Midbrain ventral', 'Pons',
             'Medulla', 'Spinal cord',
             'Enteric nervous system'] 
labels = ['Excitatory', 'Inhibitory']
label_pos = [(0,0), (1,1)]

sc.pl.DotPlot(adata_glra3, marker_genes, var_group_labels =labels, var_group_positions= label_pos, 
                          use_raw = False, groupby = 'Region', categories_order= order_cat_glra3, cmap = 'rocket_r').add_totals(color = 'rosybrown').savefig('marker_expression_glra3_cells_region.pdf')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: ImplicitModificationWarning: Initializing view as actual.
#   warnings.warn(
# Trying to set attribute `.obs` of view, copying.
# ... storing 'glra3_cell' as categorical

# %% [markdown]
# The expression prevalence of the marker genes are calculated for the Glra3 expressing neurons

# %%
percentage_exp(adata_glra3, marker_genes)
# Out:
# [('Glra3', 100.0),
#  ('Slc17a6', 31.687898089171973),
#  ('Slc32a1', 16.878980891719745)]

# %% [markdown]
# From the start, we were hoping to analyse the dataset by also taking sex into consideration. Unfortunatly for this case, the sequencing was conducted on pooled animals from both sexes and thus, we can not do this comparison.

# %%
calc_celltype_observation(adata, 'Sex')
# Out:
#           number_cells
# obs_name
# 1F               13506
# 1M                4160
# 1M 1F            10421
# 1M 2F              839
# 2M                   6
# 2M 1F             4698
# 2M 2F             1309
# ?                 1088
# F                15931
# M                19030
# M, F               146
# nan                886

# %%
calc_celltype_observation(adata_glra3, 'Sex')
# Out:
#           number_cells
# obs_name
# 1F                  65
# 1M                 119
# 1M 1F              156
# 1M 2F                3
# 2M 1F               15
# 2M 2F                1
# ?                   14
# F                  111
# M                  143
# M, F                 1

# %%
marker_genes = ['Slc17a6','Slc32a1','Glra1', 'Glra2','Glra3', 'Glra4', 'Glrb']
labels = ['Excitatory', 'Inhibitory', 'Glycine receptor']
label_pos = [(0,0), (1,1), (2,6)]
order_cat = ['Olfactory bulb', 
             'Cortex', 'Amygdala', 
             'Pallidum', 'Striatum dorsal', 
             'Striatum dorsal, Striatum ventral,Amygdala', 
             'Striatum dorsal, Striatum ventral', 'Striatum ventral', 'Striatum dorsal, Striatum ventral, Dentate gyrus',           
             'Hypothalamus', 'Thalamus', 'Hippocampus,Cortex', 'Hippocampus', 
             'Dentate gyrus', 'Midbrain dorsal', 'Midbrain dorsal,Midbrain ventral', 
             'Midbrain ventral',  'Pons,Medullae,Cerebellum', 'Cerebellum', 'Pons',
             'Medulla', 'Spinal cord', 'Sympathetic ganglion', 'Dorsal root ganglion',
             'Enteric nervous system']                                                                     

sc.pl.DotPlot(adata, marker_genes,var_group_labels =labels, 
              var_group_positions= label_pos, categories_order= order_cat,
              use_raw = False, groupby = 'Region', cmap ='mako_r').add_totals(color = 'rosybrown').savefig('glrys_expression_all_region.pdf')
